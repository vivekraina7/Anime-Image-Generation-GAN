# %% [markdown]
# #### **Agenda:**
#
# In this lecture, we'll explore the fascinating world of generative adversarial networks (GANs) and their applications in anime character generation:
#  1. We'll dive into the exciting task of generating new anime characters using GANs, a powerful technique that has revolutionized character design in recent years.
#  2. We'll delve into the architecture of GANs, exploring the intricate workings of this complex and powerful machine learning tool.
#  3. Applications of GAN

# %% [markdown]
# ###Problem Statement:
#
# `You are working as a Data Scientist at Kyoto Animation, a Japanese animation studio`
#
#
# * In 2020, about 179 new animes were released and total more than 4505 anime have been released.
#
# - Anime industry wants to develop an automated system to generate newer anime characters.
#
#
#
# <img src="https://drive.google.com/uc?export=view&id=1mHR9Ud9bFz2PtsPRnlfGIQlp11fODR5N" style="width:480px; margin-bottom:32px"/>
#
# #### How would a human create new anime characters ?
# 1. Character Profile: Choose the artistic style, skin tone, hairstyle and gesture.
# 2. Rough Character Sketches
# 3. Developing the Character Design
# 4. Coloring an Anime Character

# %% [markdown]
# # Task: Generate new anime character images
#
# ## How can we achieve this?
# - We can provide samples of anime images to our deep learning model and make it generate similar images.
#
# ### Have we encountered a similar problem before?
# - `No`
#
# ### Can we use any computer vision or CNN algorithm learned so far to solve this problem?
# - `Yes`, we can use some concepts similar to Autoencoder or U-Net architecture, where the output is the generated anime images.
#
# ### Are Autoencoders sufficient or do we need to change something?
# - `No`, Autoencoders have following limitations:
# > 1. Their goal is to learn how to reconstruct the input-data.
# > 2. They tend to overfit and they suffer from the vanishing gradient problem.
# > 3. Less variation, Generated images are too similar to the input data and no new designs.

# %% [markdown]
# # Let's have a look at a possible solution
# ## How can we achieve this?
# - `Through Generative Models`
#
# ### What are Generative models?
# > Generative modeling is an unsupervised learning task in machine learning that involves automatically discovering and learning the regularities or patterns in input data in such a way that the model can be used to generate or output new examples that plausibly could have been drawn from the original dataset.
#
#
#
# *   **More concretely, these models learn the distribution of the given training data & it generates new samples of data of the same distribution.**
#
#
#
# <img src="https://drive.google.com/uc?id=1z-Sn6f9_ahyYEcOUSj0V6AKpl5WjF7Cv" style="width:480px; margin-bottom:32px"/>

# %% [markdown]
# ### Discriminative vs Generative models?
#
# - Discriminative models draw boundaries in the data space, while generative models try to model how data is placed throughout the space.
# - A generative model focuses on explaining how the data was generated, while a discriminative model focuses on predicting the labels of the data.
#
# <img src="https://drive.google.com/uc?id=1xn2rP7N5cTtTDIUj2Bwta6-lYWvyTEP0" style="width:480px; margin-bottom:32px"/>

# %% [markdown]
# <!-- ### Why Generative Models? (ToDo) -->
# - Generative Models can generate realistic samples for artwork, super-resolution, colorization, etc.
#
# <img src="https://drive.google.com/uc?id=1yPFe-7CwcT8LBfmO5qamdXG5wz-60J9-" style="width:480px; margin-bottom:32px"/>

# %% [markdown]
# - We will be using GANS(Generative Adverserial Network) for generating new anime characters

# %% [markdown]
# # How to generate better quality images?
#
# # Can we make machines learn-to-teach themselves?
#
# - Yes, this is doable.
#
# # `What if we pitted two neural networks against each other?`
#
# # `Let us solve this using an analogy`
#
# <img src="https://drive.google.com/uc?id=16JSsm_Zcgmkbhlm48c-67QwAlzIRe_bN" style="width:480px; margin-bottom:32px"/>
#
#
#
# > - Setting off the perfect cat-and-mouse game.
#
# > - Imagine a quintessential movie where two estranged brothers embrace opposing philosophies in life. One starts a fresh underworld operation printing fake currencies as a ‘manipulator’, and the other enrols in a bureau to set up a new division that detects counterfeits as an ‘enforcer’.
#
# > - To start with, lets say that the ‘manipulator’ in underworld starts with a disadvantage of knowing nothing about what original currencies look like. The ‘enforcer’ in the bureau knows just basics of how few real currencies look.
# And then the game begins.
#
# > - The manipulator starts printing, but the initial fakes are terrible. It doesn’t need even a trained eye to detect the counterfeits, and promptly every single one of them is detected by the enforcer.
#
# > - The manipulator is industrious and keeps churning out fakes, while also learning what didn’t work in previous attempts. By sheer magnitude of experimentation with fakes & some feedback, the quality of counterfeits slowly starts inching up (of course, assuming the operation is not shut down!)
#
# > - Eventually, the manipulator starts getting a few random counterfeits right and this goes undetected by the enforcer. So, its learning time on the other side and the enforcer takes lessons on detecting these smarter counterfeits.
#
# > - With the enforcer getting smarter, the counterfeits are detected again. The manipulator has no choice but to upgrade the counterfeiting operation to create more genuine-looking fakes.
#
# > - This continuous game of cat-and-mouse continues, and ends up making experts out of both the manipulator and enforcer. So much so that the counterfeits are indistinguishable from the genuine ones, and also the detection of such ingenious fakes becomes almost uncanny.
#
# `You get the drift. And this, is the underlying concept of Generative Adversarial Networks (GANs)`

# %% [markdown]
# #### **Quiz -1**
# GANs are composed of two models that compete against each other in order to achieve equilibrium
#
# > (a) True
#
# > (b) False
#
# Ans : (a) True

# %% [markdown]
# - We could train one model to generate the data and another model to verify the quality of the generated data.
# - This approach is known as Generative Adversarial Networks (GANs)
#
# ### Introducing GANs
#
# - Both the manipulator and enforcer are models, a variant of the Deep learning neural networks.
#
# > 1. The manipulator is called the ‘Generator network’. The job of the Generator is to produce fake image that looks real so that it can fool the Discriminator.
#
# > 2. The enforcer is the ‘Discriminator network’. The job of Discriminator is to become better and better in disinguishing real and fake image.
#
# > 3. By pairing two models against each other as adversaries, we set them up for a healthy competition. Each tries mastering its own job across thousands of iterations, with no manual intervention.
#
# > 4. This way both the generator and the discriminator get better at doing their jobs.
#
#
#
# <img src="https://drive.google.com/uc?export=view&id=1OhVL4Uzzz-DD5TuCuxjsTdjEebg_bLYM" style="width:480px; margin-bottom:32px">
#
# <!-- - While there are many approaches used for generative modeling, a Generative Adversarial Network takes the following approach:
# > 1. There are two neural networks: a Generator and a Discriminator.
# > 2. The generator generates a "fake" sample given a random vector/matrix, and the discriminator attempts to detect whether a given sample is "real" (picked from the training data) or "fake" (generated by the generator).  -->
#
#
#
# <!-- GAN architecture, two network
# Difficulties related to training -->

# %% [markdown]
# **Note:** Generative modeling is an unsupervised learning task, so the images do not have any labels.
#
# - In this lecture, we'll train a GAN to generate images of anime characters.
#
# - Generative models can create plausible new data of their own.
# - But the results were often not very good: computer-generated images tended to be blurry or have errors like missing features.
#
# - GANs are extremely sensitive to hyperparameters, activation functions and regularization.

# %% [markdown]
# ## How does the data look?
#
# ### Does the dataset have any labels?
# - No, since we are going to work with unsupervised machine learning, we won't be needing any labels to train our network.

# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !gdown 1tkKn01cnF3MH7-8mQzIay7ShMcgdZXF7
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1tkKn01cnF3MH7-8mQzIay7ShMcgdZXF7
# To: /content/animefacedataset.zip
# 100% 418M/418M [00:05<00:00, 82.5MB/s]

# %%
# unzip the dataset in local directory
# !unzip '/content/animefacedataset.zip' -d '/content/animefacedataset'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/animefacedataset/content/animefacedataset/images/59232_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/6981_2003.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/4681_2003.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/58801_2017.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/37469_2012.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/31050_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/18941_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/8647_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/63412_2019.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/7296_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/38362_2012.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/25453_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/25921_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/40973_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/29125_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/18772_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/46889_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/41189_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/58111_2017.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/29202_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/28263_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/11733_2005.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/47643_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/12792_2005.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/48652_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/51581_2015.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/4762_2003.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/53747_2016.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/28736_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/38450_2012.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/25232_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/53444_2016.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/41840_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/6038_2003.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/24648_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/33313_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/16740_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/33568_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/3501_2002.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/61776_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/48729_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/35588_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/29847_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/27413_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/46513_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/20049_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/7252_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/28748_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/12339_2005.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/25458_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/2436_2001.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/14414_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/47759_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/33984_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/17029_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/18439_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/13021_2005.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/16606_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/32645_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/38533_2012.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/15039_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/23353_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/62159_2019.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/8745_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/34366_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/61852_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/8556_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/27537_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/7486_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/51600_2015.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/6532_2003.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/46697_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/16572_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/12891_2005.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/43024_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/56980_2017.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/11433_2005.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/12421_2005.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/22963_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/8148_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/17864_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/14480_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/33082_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/61908_2019.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/18710_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/43673_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/43808_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/10064_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/49571_2015.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/41226_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/51171_2015.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/47318_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/42204_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/22450_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/33536_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/8491_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/44760_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/54979_2016.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/10204_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/1279_2001.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/4866_2003.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/32570_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/59395_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/31102_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/40160_2012.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/18818_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/60146_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/44473_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/2183_2001.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/58646_2017.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/8340_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/19364_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/8061_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/61468_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/28755_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/44117_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/21810_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/15916_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/43498_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/62103_2019.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/61065_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/56202_2017.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/54720_2016.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/62865_2019.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/41971_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/34513_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/2025_2001.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/46446_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/60188_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/22557_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/15630_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/22302_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/1145_2001.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/25111_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/132_2000.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/6048_2003.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/31967_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/9356_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/23309_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/20402_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/17085_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/37525_2012.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/48806_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/56363_2017.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/30331_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/48621_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/18618_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/31484_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/42417_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/63052_2019.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/242_2000.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/36417_2012.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/47674_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/59681_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/14167_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/36170_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/31839_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/4791_2003.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/8584_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/7691_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/16616_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/28410_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/37148_2012.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/60812_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/50425_2015.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/49174_2015.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/6628_2003.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/42787_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/29411_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/12813_2005.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/15270_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/23625_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/5573_2003.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/49727_2015.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/41491_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/36583_2012.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/50045_2015.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/60968_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/21745_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/56406_2017.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/19994_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/16142_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/6478_2003.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/28744_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/25322_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/59893_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/3242_2002.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/3358_2002.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/6670_2003.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/19949_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/35123_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/38564_2012.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/52510_2016.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/39885_2012.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/34272_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/58264_2017.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/37025_2012.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/44900_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/19430_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/52874_2016.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/19512_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/18795_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/2990_2002.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/24871_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/30373_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/28765_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/58587_2017.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/60444_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/34006_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/11800_2005.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/16161_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/14524_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/41461_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/32421_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/22003_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/59011_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/27506_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/41796_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/46145_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/52853_2016.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/47834_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/44062_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/42785_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/7322_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/18_2000.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/43734_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/3338_2002.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/22644_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/59930_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/30656_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/12464_2005.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/48326_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/719_2000.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/11743_2005.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/57533_2017.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/33610_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/50886_2015.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/6175_2003.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/25694_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/39408_2012.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/47453_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/24547_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/28094_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/62994_2019.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/18101_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/15012_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/15013_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/23936_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/61741_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/33379_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/50528_2015.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/23087_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/17174_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/9038_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/29088_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/36046_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/31636_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/62701_2019.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/36272_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/50992_2015.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/52183_2015.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/9446_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/55506_2016.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/13400_2005.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/45453_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/45930_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/8610_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/41330_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/15474_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/62688_2019.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/46678_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/20676_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/60559_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/46465_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/16498_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/24240_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/24023_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/54158_2016.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/36226_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/32997_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/48672_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/47533_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/60926_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/42289_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/161_2000.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/43512_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/42258_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/54160_2016.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/6482_2003.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/56315_2017.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/21214_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/27292_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/18274_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/60562_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/26636_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/14377_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/53513_2016.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/20213_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/2145_2001.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/39889_2012.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/30081_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/7040_2003.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/41275_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/29573_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/9339_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/19553_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/32972_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/29963_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/8235_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/22107_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/20493_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/43363_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/17619_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/31609_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/6055_2003.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/25524_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/40521_2012.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/8050_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/18179_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/7478_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/23746_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/53485_2016.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/235_2000.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/61284_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/63318_2019.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/31187_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/31842_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/12628_2005.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/15793_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/25023_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/61161_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/24919_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/3140_2002.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/42989_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/27602_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/4892_2003.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/24622_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/8830_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/48456_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/7929_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/6305_2003.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/38009_2012.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/49899_2015.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/26480_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/62080_2019.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/24800_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/32747_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/58227_2017.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/61713_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/35294_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/3212_2002.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/3086_2002.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/8391_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/37094_2012.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/42435_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/2904_2002.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/1109_2001.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/50446_2015.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/17317_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/61380_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/52017_2015.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/61600_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/19475_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/48703_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/55067_2016.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/15872_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/34811_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/7529_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/26583_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/57250_2017.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/39927_2012.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/13518_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/44487_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/15451_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/2208_2001.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/45285_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/7693_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/39340_2012.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/15380_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/52976_2016.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/27835_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/63572_2019.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/38982_2012.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/3268_2002.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/42606_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/57676_2017.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/46263_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/9664_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/22904_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/28861_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/59119_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/39460_2012.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/4860_2003.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/19217_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/15584_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/57264_2017.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/15996_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/62003_2019.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/23891_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/50777_2015.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/6957_2003.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/4002_2002.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/59602_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/60284_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/49359_2015.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/10135_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/35214_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/2246_2001.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/22316_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/30894_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/12732_2005.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/56721_2017.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/7459_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/29582_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/21826_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/20780_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/9221_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/8673_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/42420_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/9998_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/27502_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/41416_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/10079_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/30723_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/57012_2017.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/50526_2015.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/46563_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/30142_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/46369_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/13582_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/48504_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/17314_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/39398_2012.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/58616_2017.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/24245_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/9031_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/27555_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/14948_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/33349_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/26879_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/47934_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/41992_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/51080_2015.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/47637_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/8309_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/13213_2005.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/4764_2003.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/63393_2019.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/40602_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/60874_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/45503_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/10023_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/51455_2015.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/59150_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/45574_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/61816_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/29875_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/1173_2001.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/35467_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/33133_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/36472_2012.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/37877_2012.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/46210_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/34000_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/8314_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/33893_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/47048_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/35206_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/18482_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/60080_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/63325_2019.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/23262_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/25825_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/27784_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/36006_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/12540_2005.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/37818_2012.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/12538_2005.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/23592_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/62319_2019.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/51114_2015.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/31669_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/33856_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/46533_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/58477_2017.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/28036_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/43483_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/63266_2019.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/52588_2016.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/17651_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/36300_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/32324_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/4732_2003.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/60059_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/41975_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/33954_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/42262_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/51990_2015.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/43085_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/8086_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/56089_2017.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/14466_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/4665_2003.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/62543_2019.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/23106_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/40218_2012.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/54406_2016.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/17562_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/63155_2019.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/33263_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/7552_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/61983_2019.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/58845_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/63102_2019.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/48349_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/8997_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/52264_2015.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/61258_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/29048_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/35729_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/18625_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/43968_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/27746_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/47775_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/20158_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/58644_2017.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/50473_2015.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/40680_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/44318_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/4955_2003.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/17629_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/61525_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/12307_2005.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/37286_2012.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/23039_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/27790_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/27951_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/41119_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/20481_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/22925_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/49068_2015.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/80_2000.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/53083_2016.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/57211_2017.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/37575_2012.jpg
# ...
#   inflating: /content/animefacedataset/content/animefacedataset/images/24034_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/818_2000.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/7393_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/31836_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/2336_2001.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/47500_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/6439_2003.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/27214_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/37394_2012.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/63439_2019.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/44020_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/28981_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/59896_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/38507_2012.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/53271_2016.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/42951_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/52185_2015.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/55921_2017.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/43369_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/23666_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/48868_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/16993_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/3584_2002.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/15050_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/16478_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/12600_2005.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/14348_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/13693_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/55086_2016.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/16969_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/14769_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/33194_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/18307_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/26844_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/2355_2001.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/56387_2017.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/35362_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/8270_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/1399_2001.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/56237_2017.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/3892_2002.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/25816_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/49918_2015.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/16766_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/39135_2012.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/27532_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/63295_2019.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/56063_2017.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/50611_2015.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/16578_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/27900_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/47731_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/15408_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/9009_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/61637_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/15746_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/58446_2017.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/29900_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/11536_2005.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/62222_2019.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/61477_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/421_2000.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/2382_2001.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/54923_2016.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/57969_2017.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/23429_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/21188_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/28841_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/14072_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/43192_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/57656_2017.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/44156_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/4684_2003.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/40603_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/11027_2005.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/29519_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/51143_2015.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/52177_2015.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/377_2000.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/62389_2019.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/62615_2019.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/15877_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/54261_2016.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/15832_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/10520_2005.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/61003_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/21491_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/21128_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/35659_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/33871_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/17209_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/22731_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/12609_2005.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/22957_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/17921_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/30363_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/47052_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/13801_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/14993_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/1193_2001.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/57643_2017.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/36626_2012.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/59644_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/48798_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/25156_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/62251_2019.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/54275_2016.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/35427_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/18984_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/14300_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/50841_2015.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/21874_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/206_2000.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/32515_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/50184_2015.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/8970_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/29256_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/37020_2012.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/29644_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/54084_2016.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/11877_2005.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/13678_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/27204_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/59500_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/47512_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/47113_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/18604_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/5232_2003.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/54396_2016.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/56811_2017.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/1531_2001.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/38914_2012.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/48919_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/35286_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/14806_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/49381_2015.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/14688_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/43006_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/449_2000.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/10593_2005.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/25139_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/50075_2015.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/19786_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/27434_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/26155_2009.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/45452_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/34422_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/45075_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/53340_2016.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/41152_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/51275_2015.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/34336_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/9911_2004.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/20865_2008.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/46768_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/63435_2019.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/29420_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/49904_2015.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/36183_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/32551_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/3958_2002.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/59850_2018.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/30387_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/36609_2012.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/11997_2005.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/16622_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/38545_2012.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/32782_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/58367_2017.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/18194_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/36449_2012.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/31068_2010.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/19688_2007.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/44609_2013.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/62778_2019.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/62666_2019.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/2440_2001.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/34624_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/14355_2006.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/35433_2011.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/45773_2014.jpg
#   inflating: /content/animefacedataset/content/animefacedataset/images/27513_2009.jpg

# %% [markdown]
# ### How many samples in the data?

# %%
import os
import gdown
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

image_dimensions = (64, 64)
batch_size = 256
# set path to the dataset
dataset_path = "./animefacedataset"

dataset = keras.preprocessing.image_dataset_from_directory(
    dataset_path, label_mode=None, image_size=image_dimensions, batch_size=batch_size
)

# scaling images to -1 to 1
dataset = dataset.map(lambda x: (x - 127.5) / 127.5)
# Out:
# Found 63565 files belonging to 1 classes.
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089

# %% [markdown]
# ### Is the data enough?
#
# ### What is the dimension of each sample image?
# - Let’s visualize some samples and check the image dimension

# %%
from matplotlib import pyplot

# Display grid of images from dataset
def display_images(total=9): # default total images to display = 9
    num=total
    for x in dataset:
        pyplot.subplot(330 + 1 + total - num)
        plt.imshow(( (x.numpy()*0.5 + 0.5) * 255).astype("int32")[0]) #pyplot.imshow((x.numpy() * 255).astype("int32")[0])
        num-=1
        if not num:
            break

# %%
display_images()

# %%
def display_single(dataloader):
    for x in dataloader:
        plt.axis("off")
        print("Image Dimensions: ",x.numpy().shape)
        plt.imshow(((x.numpy()*0.5 + 0.5) * 255).astype("int32")[0])
        break

display_single(dataset)
# Out:
# Image Dimensions:  (256, 64, 64, 3)

# %%
import numpy as np
from sklearn.utils import shuffle
import time
import cv2
from tqdm.notebook import tqdm
from PIL import Image
from keras.layers import Input, Dense, Reshape, Flatten, Dropout
from keras.layers import BatchNormalization, Activation, ZeroPadding2D
from keras.layers import LeakyReLU
from keras.layers.convolutional import UpSampling2D, Conv2D
from keras.models import Sequential, Model
from keras.layers.core import Activation
from keras.layers.core import Flatten, Dropout
from keras.layers import Input, Merge
from keras.layers.pooling import MaxPooling2D
from keras.layers.convolutional import Conv2D, Conv2DTranspose
import matplotlib.pyplot as plt
import keras.backend as K
from keras.initializers import RandomNormal

img_shape = (64, 64, 3)

# %% [markdown]
# # How does a discriminative model work?
#
# - The discriminator takes an image as input, and tries to classify it as "real" or "generated".
# - Just like any other binary classification model, the output of the discriminator is a single number between 0 and 1, which can be interpreted as the probability of the input image being real i.e. picked from the original dataset.
# - It's like any other neural network.
# - We'll use a convolutional neural networks (CNN) which outputs a single number output for every image.
# - We'll use stride of 2 to progressively reduce the size of the output feature map.
#
# - In discriminator we found the Leaky ReLU is used except at the output layer where Sigmoid is used.
#
#
#  **What is leaky ReLU ?**
#
#  - Different from the regular ReLU function, Leaky ReLU allows the pass of a small gradient signal for negative values. As a result, it makes the gradients from the discriminator flow stronger into the generator.
#
#
#  <center>  <img src='https://cdn-images-1.medium.com/max/1600/1*ypsvQH7kvtI2BhzR2eT_Sw.png' width=400 height=200></center>
#
#
#
#
# #### **Quiz-2**
# Why do we require LeakyReLU in discriminator ?
#
# > (a) It will help the discriminator to distinguish between real and fake image
#
# > (b) It will help the generator to learn as gradient will flow always from the discriminator
#
# > (c) It is computationally inexpensive
#
# > (d) It will saturate
#
# Ans : (b) It will help the generator to learn as gradient will flow always from the discriminator. If ReLU was used then the Generator would learn only from the positive gradients but in Leaky ReLU the Generator will learn from both positive and negative gradient

# %% [markdown]
# # Architecture of Discriminator
#
# <img src="https://drive.google.com/uc?export=view&id=1MEOlkGZnLGr1m0f2QVEupenj-OiFTlYR" style="width:480px; margin-bottom:32px">

# %%
def get_disc_normal(image_shape=(64,64,3)):
    image_shape = image_shape
    
    dropout_prob = 0.4
    
    #kernel_init = RandomNormal(mean=0.0, stddev=0.01)
    kernel_init = 'glorot_uniform'
    
    dis_input = Input(shape = image_shape)
    
    discriminator = Conv2D(filters = 64, kernel_size = (4,4), strides = (2,2), padding = "same", data_format = "channels_last", kernel_initializer = kernel_init)(dis_input)
    discriminator = LeakyReLU(0.2)(discriminator)
    #discriminator = MaxPooling2D(pool_size=(2, 2))(discriminator)
    
    #discriminator = Dropout(dropout_prob)(discriminator)
    discriminator = Conv2D(filters = 128, kernel_size = (4,4), strides = (2,2), padding = "same", data_format = "channels_last", kernel_initializer = kernel_init)(discriminator)
    discriminator = BatchNormalization(momentum = 0.5)(discriminator)
    discriminator = LeakyReLU(0.2)(discriminator)
    #discriminator = MaxPooling2D(pool_size=(2, 2))(discriminator)
    
    #discriminator = Dropout(dropout_prob)(discriminator)
    discriminator = Conv2D(filters = 256, kernel_size = (4,4), strides = (2,2), padding = "same", data_format = "channels_last", kernel_initializer = kernel_init)(discriminator)
    discriminator = BatchNormalization(momentum = 0.5)(discriminator)
    discriminator = LeakyReLU(0.2)(discriminator)
    #discriminator = MaxPooling2D(pool_size=(2, 2))(discriminator)
    
    #discriminator = Dropout(dropout_prob)(discriminator)
    discriminator = Conv2D(filters = 512, kernel_size = (4,4), strides = (2,2), padding = "same", data_format = "channels_last", kernel_initializer = kernel_init)(discriminator)
    discriminator = BatchNormalization(momentum = 0.5)(discriminator)
    discriminator = LeakyReLU(0.2)(discriminator)
    #discriminator = MaxPooling2D(pool_size=(2, 2))(discriminator)
    
    discriminator = Flatten()(discriminator)
    
    #discriminator = MinibatchDiscrimination(100,5)(discriminator)
    discriminator = Dense(1)(discriminator)
    discriminator = Activation('sigmoid')(discriminator)
    
    discriminator_model = Model(dis_input, discriminator)
    discriminator_model.summary()
    return discriminator_model

# %%
discriminator = get_disc_normal()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 3)]       0
#
#  conv2d (Conv2D)             (None, 32, 32, 64)        3136
#
#  leaky_re_lu (LeakyReLU)     (None, 32, 32, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 128)       131200
#
#  batch_normalization (BatchN  (None, 16, 16, 128)      512
#  ormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 16, 16, 128)       0
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 256)         524544
#
#  batch_normalization_1 (Batc  (None, 8, 8, 256)        1024
#  hNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 8, 8, 256)         0
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 512)         2097664
#
#  batch_normalization_2 (Batc  (None, 4, 4, 512)        2048
#  hNormalization)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 4, 4, 512)         0
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 1)                 8193
#
#  activation (Activation)     (None, 1)                 0
#
# =================================================================
# Total params: 2,768,321
# Trainable params: 2,766,529
# Non-trainable params: 1,792
# _________________________________________________________________

# %% [markdown]
# ####**Quiz-2**
# Why does discriminator does not use the GAP(Global Average Pooling) followed by FC layers after the Conv Layer ?
#
# > (a) Because we can pass input  image of any shape if FC layers are not used
#
# > (b) To reduce the no of parameters as FC layers will increase the number of parameters
#
# > (c) GAP increase the model stability but it hurts the convergence of GAN
#
#   Ans: (c) GAP increase the model stability but it hurts the convergence of GAN.
#       Refer Page 3 of DCGAN paper [Click to know more](https://arxiv.org/pdf/1511.06434.pdf )

# %% [markdown]
# ## How does a generator model work?
#
# - The input to the generator is typically a vector or a matrix of random numbers (referred to as a latent tensor) which is used as a seed for generating an image.
#
# - The generator will convert a latent tensor of shape (128, 1, 1) into an image tensor of shape 3 x 64 x 64.
#
# - To achieve this, we'll use the Conv2DTranspose layer from Keras, which is performed as a transposed convolution (also referred to as a deconvolution).
#
# - In generator, ReLU is used except at the output layer where tanh activation function is used
#
#
#  <center>  <img src='https://nic.schraudolph.org/teach/NNcourse/figs/tanh.gif' width=400 height=200></center>
#
#
#
#
#
#
# #### **Quiz-3**
# Why was the real image standardized to a range of [-1,1] ?
#
# > (a) The outputs of the tanh activation lie in the range [-1,1] so thats why we have applied the similar transformation to the images in the training dataset.
#
# > (b) Standardization of image to a range of [-1,1] is better than range of [0,1]
#
# > (c) Image standardized to a range of [-1,1] will be zero centered
#
# > (d) We could have standardized image to range of [-1,1] or [0,1].  Both will work equally good
#
# Ans (a)  The outputs of the tanh activation lie in the range [-1,1] so thats why we have applied the similar transformation to the images in the training dataset.
#
# ### So how does a deconvolution layer works?
# - A deconvolution is a mathematical operation that reverses the effect of convolution.
#
#
# - For example, lets take input matrix of shape 2x2 and kernel of shape 2x2. We'll get the output matrix of shape 3x3.
#
# <img src="https://d2l.ai/_images/trans_conv.svg" style="width:480px; margin-bottom:32px"/>

# %% [markdown]
# # Architecture of Generator
#
# <img src="https://drive.google.com/uc?export=view&id=1DB9pihbCUoGax2A87J-dT6hrtAxd_Rnz" style="width:480px; margin-bottom:32px">

# %%
latent_dim = 128

def get_gen_normal(noise_shape = (1,1,128)):
    noise_shape = noise_shape
    """
    Changing padding = 'same' in the first layer makes a lot fo difference!!!!
    """
    #kernel_init = RandomNormal(mean=0.0, stddev=0.01)
    kernel_init = 'glorot_uniform'
    
    gen_input = Input(shape = noise_shape) #if want to directly use with conv layer next
    #gen_input = Input(shape = [noise_shape]) #if want to use with dense layer next
    
    generator = Conv2DTranspose(filters = 512, kernel_size = (4,4), strides = (1,1), padding = "valid", data_format = "channels_last", kernel_initializer = kernel_init)(gen_input)
    generator = BatchNormalization(momentum = 0.5)(generator)
    generator = LeakyReLU(0.2)(generator)
        
    generator = Conv2DTranspose(filters = 256, kernel_size = (4,4), strides = (2,2), padding = "same", data_format = "channels_last", kernel_initializer = kernel_init)(generator)
    generator = BatchNormalization(momentum = 0.5)(generator)
    generator = LeakyReLU(0.2)(generator)
    
    generator = Conv2DTranspose(filters = 128, kernel_size = (4,4), strides = (2,2), padding = "same", data_format = "channels_last", kernel_initializer = kernel_init)(generator)
    generator = BatchNormalization(momentum = 0.5)(generator)
    generator = LeakyReLU(0.2)(generator)
    
    generator = Conv2DTranspose(filters = 64, kernel_size = (4,4), strides = (2,2), padding = "same", data_format = "channels_last", kernel_initializer = kernel_init)(generator)
    generator = BatchNormalization(momentum = 0.5)(generator)
    generator = LeakyReLU(0.2)(generator)
    
    generator = Conv2D(filters = 64, kernel_size = (3,3), strides = (1,1), padding = "same", data_format = "channels_last", kernel_initializer = kernel_init)(generator)
    generator = BatchNormalization(momentum = 0.5)(generator)
    generator = LeakyReLU(0.2)(generator)
    
    generator = Conv2DTranspose(filters = 3, kernel_size = (4,4), strides = (2,2), padding = "same", data_format = "channels_last", kernel_initializer = kernel_init)(generator)
    generator = Activation('tanh')(generator)
        
    generator_model = Model(gen_input, generator)
    generator_model.summary()

    return generator_model

# %%
generator = get_gen_normal()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 1, 1, 128)]       0
#
#  conv2d_transpose (Conv2DTra  (None, 4, 4, 512)        1049088
#  nspose)
#
#  batch_normalization_3 (Batc  (None, 4, 4, 512)        2048
#  hNormalization)
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 4, 4, 512)         0
#
#  conv2d_transpose_1 (Conv2DT  (None, 8, 8, 256)        2097408
#  ranspose)
#
#  batch_normalization_4 (Batc  (None, 8, 8, 256)        1024
#  hNormalization)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 8, 8, 256)         0
#
#  conv2d_transpose_2 (Conv2DT  (None, 16, 16, 128)      524416
#  ranspose)
#
#  batch_normalization_5 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 16, 16, 128)       0
#
#  conv2d_transpose_3 (Conv2DT  (None, 32, 32, 64)       131136
#  ranspose)
#
#  batch_normalization_6 (Batc  (None, 32, 32, 64)       256
#  hNormalization)
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 32, 32, 64)        0
#
#  conv2d_4 (Conv2D)           (None, 32, 32, 64)        36928
#
#  batch_normalization_7 (Batc  (None, 32, 32, 64)       256
#  hNormalization)
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 32, 32, 64)        0
#
#  conv2d_transpose_4 (Conv2DT  (None, 64, 64, 3)        3075
#  ranspose)
#
#  activation_1 (Activation)   (None, 64, 64, 3)         0
#
# =================================================================
# Total params: 3,846,147
# Trainable params: 3,844,099
# Non-trainable params: 2,048
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(generator)

# %% [markdown]
# ## How to train GANs?
# ### Discriminator Training
#
# - Since the discriminator is a binary classification model, we can use the `binary cross entropy loss function` to quantify how well it is able to differentiate between real and generated images.
#
# - The binary cross entropy loss is defined as:
#
#  > $-\frac{1}{N} \sum_{i=1}^{N} y_{i}log(h_{\theta}(x_{i}))+(1-y_{i})log(1-h_{\theta}(x_{i}))$
#
#
#
# **Here are the steps involved in training the discriminator:**
#
# - We expect the discriminator to output 1 if the image was picked from the real Anime Face dataset, and 0 if it was generated using the generator network.
# - We first pass a batch of real images, and compute the loss, setting the target labels to 1.
#
#   <center><img src='https://drive.google.com/uc?id=1X_FXmZSSV5VSrX50wd5KFzN2S5Ip4Gd5' ></center>
#
# - Then we pass a batch of fake images of anime (generated using the generator) pass them into the discriminator, and compute the loss, setting the target labels to 0.
#   <center><img src='https://drive.google.com/uc?id=1hBVeEEDVU2dfeicAFHq1PKURnrDarALP' ></center>
#
# - Finally we add the two losses and use the overall loss to perform gradient descent to adjust the weights of the discriminator.
#
#   <center><img src='https://drive.google.com/uc?id=1IwWAdXE91mQAh4hjP-5HIAfiZkibNgTX' ></center>
#
#
# > *It's important to note that we don't change the weights of the generator model while training the discriminator (opt_d only affects the discriminator.parameters())*
#
#
#
#
# ### Discriminator loss
#
# > 1. Z: Noise vector (Dimension of the noise vector is a hyperparameter).
# > 2. G(Z): Output of the generator when given the noise vector Z.
# > 3. X: Real Training data.
# > 4. D(G(Z)): Output of the discriminator when given fake generated data or G(Z).
# > 5. D(X): Output of the discriminator when given real training data from X.
#
# - The discriminator takes either X or G(Z). Note that the discriminator is nothing but a binary classifier so, we label D(X) as 1 and D(G(Z)) as 0.
#
# - We want our discriminator to label all D(X) as 1 and all D(G(Z)) as 0. So how can we achieve this?
#
#  1. Given, real image as input $X$ , the predicted value is $D(X)$ and the label is 1. Therefore the loss function is,
#    - $L(D(X),1)=1.log D(X)+(1-1). log(1-D(X)) = log D(X)$
#
#    - The discriminator should maximize Log(D(X)), and as Log is a monotonic function so log(D(X)) will automatically get maximized if the discriminator maximized D(X).
#
#  2. Given, $G(Z)$ as input to Discriminator, the predicted value is $D(G(Z))$ and the label is 0. Therefore the loss function is,
#    - $L(D(G(Z)),0)=0.log D(G(Z))+(1-0).log(1-D(G(Z))) =log(1-D(G(Z))) $
#    - The discriminator needs to maximize log(1 — D(G(Z))), which means it must have to minimize D(G(Z)).
#
# - So, the loss function for the discriminator (for a single sample) becomes,
#
#  > $max [log D(X)+log(1-D(G(Z))]$
#
#
# - Now, the loss function of the discriminator over a batch is,
#
#  > $max[E_{(X\sim P(X))}[log D(X)]+E_{Z\sim P(Z)}[log(1-D(G(Z)))]]$
#
#    where, <br/>
#   P(X) is the probability distribution of real training data <br />
#    P(Z) is the probability distribution of the noise vector Z.<br/> Typically, P(Z) is gaussian or Uniform.
#
#
# - **The following equation is maximized for training the discriminator**
#
#  > $\underset{D} max\frac{1}{m}\sum_{i=1}^{m}[log D (x^i)+log(1-D(G(z^i)))]$.
#
#
# > **Note:** that, D(X) and D(G(Z)) both are probability values and **both of them lie in between 0 and 1.**

# %% [markdown]
# ---
# ---
#
# ### Generator Training
# - Since the outputs of the generator are images, it's not obvious how we can train the generator.
# - This is where we employ a rather elegant trick, which is to use the discriminator as a part of the loss function.
#
#
# - Here's how it works:
#  - We generate a batch of images using the generator, pass the into the discriminator.
#    <center><img src='https://drive.google.com/uc?id=1IvLgQHUK5GiCtxf65PXELdFUers1ZD_l' ></center>
#
#  - We calculate the loss by setting the target labels to 1 i.e. real. We do this because the generator's objective is to "fool" the discriminator.
#
#  - We use the loss to perform gradient descent i.e. change the weights of the generator, so it gets better at generating real-like images to "fool" the discriminator.
#
#    <center><img src='https://drive.google.com/uc?id=145BLaAMwztTIjg5LnLAe_jbT8hlpj6vU' ></center>
#
#
# ### Generator loss
#
# - The Generator needs to fool the discriminator by generating images as real as possible. This means the generator should generate such G(Z) which if we pass through the discriminator will label is as 1.
#
# - So, discriminator wants to make D(G(Z)) equal to 1 and generator wants to make D(G(Z)) equal to 0.Thus the loss function is,
#   - $L(D(G(Z)),0)=log(1-D(G(Z)))$
#
#
# - The above one is for just one sample. Over a batch, it will be,
#
#  - $L(D(G(Z)),0)=E_{Z\sim P(Z)}[log(1-D(G(Z)))]$
#
#
# - The generator will minimize the above loss function and to minimize the above the generator must maximize D(G(Z)). Now, it is very clear that **the discriminator wants to minimize D(G(Z)) and the generator wants to maximize D(G(Z)).**
#
# - Understand that, the generator is never going to see any real data but for completeness, the generator loss function can be written as follows!
#
#  > $min[E_{(X\sim P(X))}[log D(X)]+E_{(Z\sim P(Z))}[log(1-D(G(Z)))]]$
#
#
#  > **Note:** the generator has no control over the first term so the **generator will only minimize the second term.**
#
#
# - **The following equation is minimized for training the generator:**
#
#  - $\underset{G} min \frac{1}{m}\sum_{i=1}^{m}log(1-D(G(Z^i)))$.
#
# - **Or, we can maximize the following for training the generator:**
#  - $\underset{G} max \frac{1}{m}\sum_{i=1}^{m}log(D(G(Z^i)))$.

# %% [markdown]
# ####**Quiz-4**
#
# For training the GAN generator, which of the following is used :
#   1. $ \underset{G}  max \frac{1}{m}\sum_{i=1} ^{m}log(D(G(Z^i)))$
#
#   2. $  \underset{G} min  \frac{1}{m}\sum_{i=1} ^{m}log(1-D(G(Z^i)))$
#
# > (a) 1
#
# > (b) 2
#
# > (c) Either 1 or 2
#
# > (d) None of the above
#
# Ans (a) 1 .Although both 1 and 2 are same, but for training 1 is better for gradients to flow. [Click for more details ](https://www.youtube.com/watch?v=1ju4qmdtRdY&t=1085s)

# %% [markdown]
# ---
# ---
#
# ### Full Training Loop
#
# - Assume that, D is the parameters of the Discriminator and G is the parameters of the generator. So, we can write the loss function as,
#
#  - $\underset{G} min \, \underset{D} max  [E_{{(X\sim P(X))}}[log D(X)]+E_{(Z\sim P(Z))}[log(1-D(G(Z)))]]$
#
#
#
#
# - **This means the discriminator parameters (defined by D) will maximize the loss function and the generator parameters (defined by G) will minimize the loss function.**
#
# - The adversarial loss can be optimized by gradient descent. But while training a GAN **we do not train the generator and discriminator simultaneously**, while training the generator we freeze the discriminator and vice-versa!
#
#
#
#
# ###Do you expect that GANs training is as smooth as we train other deep learning models?
#
# - Since two deep learning models are in a constant fight. One model might overpower the other, which can degrade the quality of generated images
#
# - For GANs, we expect the generator's loss to reduce over time, without the discriminator's loss getting too high.
# </br>
#
# ### Algorithm
#
#  **for** number of training iterations **do**
#
#
#   - Sample minibatch of *m* noise samples {$z^1,.....,z^m$} from noise prior $p_{g}$(z).
#   - Sample minibatch of *m* examples {$x^1,.....,x^m$} from data generating
#   distribution $p_{data}$(x).
#   - Update the discriminator by ascending its stochastic gradient:
#    - $\nabla_{Θ_{d}}\frac{1}{m}\sum_{i=1}^{m}[log D (x^i)+log(1-D(G(z^i)))]$.
#
#
#
#   - Sample minibatch of *m* noise samples {$z^1,.....,z^m$} from noise prior $p_{g}$(z).
#   - Update the generator by ascending its stochastic gradient:
#
#    - $\nabla_{Θ_{g}}\frac{1}{m}\sum_{i=1}^{m}log(D(G(Z^i)))$.
#
#
#
# **end for**

# %%
class GAN(keras.Model):
    def __init__(self, discriminator, generator, latent_dim):
        super(GAN, self).__init__()
        self.discriminator = discriminator
        self.generator = generator
        self.latent_dim = latent_dim

    def compile(self, d_optimizer, g_optimizer, loss_fn):
        super(GAN, self).compile()
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer
        self.loss_fn = loss_fn
        self.d_loss_metric = keras.metrics.Mean(name="d_loss")
        self.g_loss_metric = keras.metrics.Mean(name="g_loss")

    @property
    def metrics(self):
        return [self.d_loss_metric, self.g_loss_metric]

    def train_step(self, real_images):
        # Sample random points in the latent space
        batch_size = tf.shape(real_images)[0]
        random_latent_vectors = tf.random.normal(shape=(batch_size, 1, 1, self.latent_dim))

        # Decode them to fake images
        generated_images = self.generator(random_latent_vectors)

        # Combine them with real images?
        combined_images = tf.concat([generated_images, real_images], axis=0)

        # # Assemble labels discriminating real from fake images
        # labels = tf.concat(
        #     [tf.ones((batch_size, 1)), tf.zeros((batch_size, 1))], axis=0
        # )

        # Assemble labels discriminating real from fake images
        labels = tf.concat(
            [tf.zeros((batch_size, 1)), tf.ones((batch_size, 1))], axis=0
        )

        # Add random noise to the labels - important trick!
        # labels += 0.05 * tf.random.uniform(tf.shape(labels))

        # Train the discriminator
        with tf.GradientTape() as tape:
            predictions = self.discriminator(combined_images)
            d_loss = self.loss_fn(labels, predictions)
        grads = tape.gradient(d_loss, self.discriminator.trainable_weights)
        self.d_optimizer.apply_gradients(
            zip(grads, self.discriminator.trainable_weights)
        )

        # Sample random points in the latent space
        random_latent_vectors = tf.random.normal(shape=(batch_size, 1, 1, self.latent_dim))

        # # Assemble labels that say "all real images"
        # misleading_labels = tf.zeros((batch_size, 1))
        # Assemble labels that say "all real images"
        misleading_labels = tf.ones((batch_size, 1))

        # Train the generator (note that we should *not* update the weights
        # of the discriminator)!
        with tf.GradientTape() as tape:
            predictions = self.discriminator(self.generator(random_latent_vectors))
            g_loss = self.loss_fn(misleading_labels, predictions)
        grads = tape.gradient(g_loss, self.generator.trainable_weights)
        self.g_optimizer.apply_gradients(zip(grads, self.generator.trainable_weights))

        # Update metrics
        self.d_loss_metric.update_state(d_loss)
        self.g_loss_metric.update_state(g_loss)
        return {
            "d_loss": self.d_loss_metric.result(),
            "g_loss": self.g_loss_metric.result(),
        }

# %% [markdown]
# The function save_img_batch will save the batch of images generated by GANS.

# %%
import matplotlib.gridspec as gridspec

def save_img_batch(img_batch,img_save_dir):
    img_batch.numpy()
    plt.figure(figsize=(4,4))
    gs1 = gridspec.GridSpec(4, 4)
    gs1.update(wspace=0, hspace=0)
    rand_indices = np.random.choice(img_batch.shape[0],16,replace=False)
    #print(rand_indices)
    for i in range(16):
        #plt.subplot(4, 4, i+1)
        ax1 = plt.subplot(gs1[i])
        ax1.set_aspect('equal')
        rand_index = rand_indices[i]
        image = img_batch[rand_index, :,:,:]
        fig = plt.imshow(image)
        plt.axis('off')
        fig.axes.get_xaxis().set_visible(False)
        fig.axes.get_yaxis().set_visible(False)
    plt.tight_layout()
    plt.savefig(img_save_dir,bbox_inches='tight',pad_inches=0)
    plt.show()

# %% [markdown]
# - GANS are very difficult to train. So we will be monitoring the output of the GANS generator after every epoch and save the batch of generated images

# %%
class GANMonitor(keras.callbacks.Callback):
    def __init__(self, num_img=16, latent_dim=128, file_writer=None):
        self.num_img = num_img
        self.latent_dim = latent_dim
        self.file_writer = file_writer
        self.random_latent_vectors = tf.random.normal(shape=(self.num_img, 1, 1, self.latent_dim))
        # Directory to save generated outputs after each epoch
        self.path = './generate_per_epoch'
        if not os.path.exists(self.path):
            os.mkdir(self.path)


    def on_epoch_end(self, epoch, logs=None):
        # random_latent_vectors = tf.random.normal(shape=(self.num_img, 1, 1, self.latent_dim)) 
        generated_images = self.model.generator(self.random_latent_vectors)
        generated_images = (generated_images*0.5 + 0.5) 
        # generated_images.numpy()
        save_img_batch(generated_images, self.path + '/' + 'generated_img_%03d.png' % (epoch) )

        # Convert to image and log
        with self.file_writer.as_default():
            tf.summary.image("Epoch end generated data", generated_images, step=epoch)

        # img = keras.preprocessing.image.array_to_img(generated_images)
        # img.save("generated_img_%03d.png" % (epoch))
        # for i in range(self.num_img):
        #     img = keras.preprocessing.image.array_to_img(generated_images[i])
        #     img.save("generated_img_%03d_%d.png" % (epoch, i))

# %% [markdown]
# - You need to save the logs in the tensorboard so that it can be viewed and loaded any time

# %%
training_log_dir = './logs/training_logs'
epoch_end_logdir = './logs/epoch_end_logs'

# %% [markdown]
# ###**Quiz-5**
#  Normaly while training a neural network we use Adam optimizer with a default $\beta1$ = 0.9 and $\beta2$ = 0.99 but while training GAN we set $\beta1$ to 0.5 . What is the reason behind this:
# >  (a) We can use the default value of $\beta1$
#
# > (b)  To help the discriminator distinguish between real and fake image
#
# > (c)  To achieve more stability in training the GAN
#
#  Ans: (c) To achieve more stability in training the GAN . Refer to section DETAILS OF ADVERSARIAL TRAINING in the [paper](https://arxiv.org/pdf/1511.06434.pdf)

# %%
epochs = 60  #  try ~100 epochs
latent_dim = 128
# training_log_dir = "./drive/MyDrive/Datasets - DSML/IntroToGANs/logs/training_logs"

# Sets up a timestamped log directory.
# epoch_end_logdir = "./drive/MyDrive/Datasets - DSML/IntroToGANs/logs/epoch_end_logs"
# Creates a file writer for the log directory.
file_writer = tf.summary.create_file_writer(epoch_end_logdir)

gan = GAN(discriminator=discriminator, generator=generator, latent_dim=latent_dim)
gan.compile(
    d_optimizer=keras.optimizers.Adam(learning_rate=0.0002, beta_1=0.5),
    g_optimizer=keras.optimizers.Adam(learning_rate=0.00015, beta_1=0.5),
    loss_fn=keras.losses.BinaryCrossentropy(),
)

tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=training_log_dir, histogram_freq=1)

# %% [markdown]
# - Start training the GANS and observe the generated output after every epoch

# %%
# %%time
history = gan.fit(
                    dataset, epochs=epochs, 
                    callbacks=[GANMonitor(num_img=16, latent_dim=latent_dim, file_writer=file_writer), 
                             tensorboard_callback])

# %% [markdown]
# **How the loss changes over time?**
# - Visualizing losses is quite useful for debugging the training process.
#  > For GANs, we expect: the generator's loss to reduce over time, without the discriminator's loss getting too high.

# %%
from tensorflow.keras.callbacks import TensorBoard
training_log_dir = './logs/training_logs/train'

# %%
# %reload_ext tensorboard
# %tensorboard --logdir={training_log_dir}

# %% [markdown]
# ### Why did discriminator loss increase?
#
# - Discriminator consist of two loss parts (1st: detect real image as real; 2nd detect fake image as fake). 'Full discriminator loss' is sum of these two parts.
#
# - The loss should be as small as possible for both the generator and the discriminator. But there is a catch: the smaller the discriminator loss becomes, the more the generator loss increases and vice versa.
#
# - The images are getting more realistic (which is all we really care about) so the generator's loss is improving, while the discriminator is doing the same quality job, but getting tougher data.

# %%
epoch_end_logdir = './logs/epoch_end_logs'

# %reload_ext tensorboard
# %tensorboard --logdir={epoch_end_logdir}

# %%
pretrained_weights = "/content/pretrained_weights"
if not os.path.exists(pretrained_weights):
  os.makedirs(pretrained_weights)

# %%
# Load Model Weights if required
generator.save(os.path.join(pretrained_weights,'generator.h5'))
discriminator.save(os.path.join(pretrained_weights,'discriminator.h5'))

#generator     = tf.keras.models.load_model("/content/drive/MyDrive/DSML_Course_Curriculum/Intro_to_GANs/pretrained_weights/generator.h5")
#discriminator = tf.keras.models.load_model("/content/drive/MyDrive/DSML_Course_Curriculum/Intro_to_GANs/pretrained_weights/discriminator.h5")
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ### Full Training as a GIF:
# Here's how the generated images look, after every epoch of training.

# %%
import imageio
# loading all generated images
images = []
gen_img_path =  '/content/generate_per_epoch/'
filenames = [os.path.join(gen_img_path, f) for f in os.listdir(gen_img_path) if 'generated' in f]
filenames.sort()

# Saving as gif file
for filename in filenames:
    images.append(imageio.imread(filename))
imageio.mimsave('/content/movie.gif', images)

# %%
from IPython.display import Image
# Display gif 
Image(open('/content/movie.gif','rb').read())

# %% [markdown]
# We can visualize the training process by combining the sample images generated after each epoch into a video using OpenCV.

# %% [markdown]
# ##`GANs however, can be notoriously difficult to train, and are extremely sensitive to hyperparameters, activation functions and regularization.`
#
# ## What are the difficulties with training GANs?
#
# **1. Vanishing Gradient**
# > - If the Discriminator is too good , then generator training can fail due to vanishing gradients.
# > - An optimal discriminator doesn't provide enough information  for the generator to progress.
# > - When we apply backpropagation, we use the chain rule of differentiation, which has a multiplying effect.
# > - Thus, gradient flows backward, from the final layer to the first layer. As it flows backward, it gets increasingly smaller.
# > - Sometimes, the gradient is so small that the initial layers learn very slowly or stop learning completely.
# > - Hence the generator fails to generate real quality images.
#
#
# **2. Mode Collapse:**
#
# > - Most of the times the data we have is multimodal, which means it has multiple modes where each mode represents data which share similar features.
# > - A very common problem while training GANs is Mode Collapse in which the Generator produces images belonging to only a few modes of the data and ignores all other modes, hence the generated images are very similar and lack variety.
# > - Experimenting with the Learning Rate of both Generator and Discriminator could help in overcoming this problem. So while training your GANs you should monitor the generated samples to see if your model is suffering from this problem.

# %%
# Hyperparameters
batch_size = 512
epochs = 60 
latent_dim = 100
image_dimensions = (64, 64)

# dataloader
dataset_path = "./animefacedataset"
dataset = keras.preprocessing.image_dataset_from_directory(
    dataset_path, label_mode=None, image_size=image_dimensions, batch_size=batch_size
)

# Model initialization
generator = get_gen_normal(noise_shape = (1,1,latent_dim))
discriminator = get_disc_normal()

# path to log folder
training_log_dir = './mode_collapse_logs/training_logs'
epoch_end_logdir = './mode_collapse_logs/epoch_end_logs'

# Sets up a timestamped log directory.
# Creates a file writer for the log directory.
file_writer = tf.summary.create_file_writer(epoch_end_logdir)

# callbacks
gan = GAN(discriminator=discriminator, generator=generator, latent_dim=latent_dim)
gan.compile(
    d_optimizer=keras.optimizers.Adam(learning_rate=0.0002, beta_1=0.5),
    g_optimizer=keras.optimizers.Adam(learning_rate=0.00015, beta_1=0.5),
    loss_fn=keras.losses.BinaryCrossentropy(),
)

tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=training_log_dir, histogram_freq=1)
# Out:
# Found 63565 files belonging to 1 classes.
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 1, 1, 100)]       0
#
#  conv2d_transpose_15 (Conv2D  (None, 4, 4, 512)        819712
#  Transpose)
#
#  batch_normalization_24 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  leaky_re_lu_27 (LeakyReLU)  (None, 4, 4, 512)         0
#
#  conv2d_transpose_16 (Conv2D  (None, 8, 8, 256)        2097408
#  Transpose)
#
#  batch_normalization_25 (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  leaky_re_lu_28 (LeakyReLU)  (None, 8, 8, 256)         0
#
#  conv2d_transpose_17 (Conv2D  (None, 16, 16, 128)      524416
#  Transpose)
#
#  batch_normalization_26 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  leaky_re_lu_29 (LeakyReLU)  (None, 16, 16, 128)       0
#
#  conv2d_transpose_18 (Conv2D  (None, 32, 32, 64)       131136
#  Transpose)
#
#  batch_normalization_27 (Bat  (None, 32, 32, 64)       256
#  chNormalization)
#
#  leaky_re_lu_30 (LeakyReLU)  (None, 32, 32, 64)        0
#
#  conv2d_15 (Conv2D)          (None, 32, 32, 64)        36928
#
#  batch_normalization_28 (Bat  (None, 32, 32, 64)       256
#  chNormalization)
#
#  leaky_re_lu_31 (LeakyReLU)  (None, 32, 32, 64)        0
#
#  conv2d_transpose_19 (Conv2D  (None, 64, 64, 3)        3075
#  Transpose)
#
#  activation_6 (Activation)   (None, 64, 64, 3)         0
#
# =================================================================
# Total params: 3,616,771
# Trainable params: 3,614,723
# Non-trainable params: 2,048
# _________________________________________________________________
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 64, 64, 3)]       0
#
#  conv2d_16 (Conv2D)          (None, 32, 32, 64)        3136
#
#  leaky_re_lu_32 (LeakyReLU)  (None, 32, 32, 64)        0
#
#  conv2d_17 (Conv2D)          (None, 16, 16, 128)       131200
#
#  batch_normalization_29 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  leaky_re_lu_33 (LeakyReLU)  (None, 16, 16, 128)       0
#
#  conv2d_18 (Conv2D)          (None, 8, 8, 256)         524544
#
#  batch_normalization_30 (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  leaky_re_lu_34 (LeakyReLU)  (None, 8, 8, 256)         0
#
#  conv2d_19 (Conv2D)          (None, 4, 4, 512)         2097664
#
#  batch_normalization_31 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  leaky_re_lu_35 (LeakyReLU)  (None, 4, 4, 512)         0
#
#  flatten_3 (Flatten)         (None, 8192)              0
#
#  dense_3 (Dense)             (None, 1)                 8193
#
#  activation_7 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 2,768,321
# Trainable params: 2,766,529
# Non-trainable params: 1,792
# _________________________________________________________________

# %%
history = gan.fit(
                  dataset, epochs=epochs, 
                  callbacks=[GANMonitor(num_img=16, latent_dim=latent_dim, file_writer=file_writer), 
                             tensorboard_callback])

# %% [markdown]
# ### Applications of GAN

# %% [markdown]
# #### StyleGAN
#
# - The **StyleGAN** is a continuation of the progressive, developing GAN, which is a proposal for training generator models to synthesise massive high-quality photographs through the incremental development of both discriminator and generator models from minute to extensive images.
# [Click to know more](https://arxiv.org/pdf/1812.04948.pdf)
#
# <center><img src="https://drive.google.com/uc?export=view&id=1duqIpsCcIWnXVEor_bNbR5e4V_ujtDkK" style="width:480px; margin-bottom:32px">

# %% [markdown]
# ### SRGAN
#
# - Super-resolution GAN applies a deep network in combination with an adversary network to produce higher resolution images.
# - SRGAN is more appealing to a human with more details compared with the similar design without GAN.
# - During the training, A high-resolution image (HR) is downsampled to a low-resolution image (LR).
# - A GAN generator upsamples LR images to super-resolution images (SR). [Click to know more](https://arxiv.org/pdf/1609.04802.pdf)
#
# <center><img src="https://drive.google.com/uc?id=1L5WMWtOcVTd0wgKTuzalsOEd5OUcMW6g" style="width:200px; margin-bottom:32px">

# %% [markdown]
# ### Cycle GAN
#
# - CycleGAN is used to enable training without the need for paired data.
#
# - Cycle GAN is used to transfer characteristic of one image to another or can map the distribution of images to another.
# - In CycleGAN we treat the problem as an image reconstruction problem.
# - We first take an image input (x) and using the generator G to convert into the reconstructed image.
# - Then we reverse this process from reconstructed image to original image using a generator F.
# - Then we calculate the mean squared error loss between real and reconstructed image.
# - The most important feature of this cycleGAN is that it can do this image translation on an unpaired image where there is no relation exists between the input image and output image. [Click to know more](https://arxiv.org/pdf/1703.10593.pdf)
#
#
# <center><img src="https://drive.google.com/uc?id=1Pb86onhjmcf8137QjIxZBPZy_NsNcam2" style="width:200px; margin-bottom:32px">

# %% [markdown]
# ### Homework Exercise to follow[OPTIONAL]:
# - Generating artificial MRI images of different contrast levels from existing MRI scans-
#
#     https://drive.google.com/drive/folders/1FurWbA-fqumW3iuouH00XhJJkM25vkTe?usp=sharing

# %% [markdown]
# ## Useful Resources:
#
# ### Cheatsheet for whole summary of CNN :
# - https://stanford.edu/~shervine/teaching/cs-230/cheatsheet-convolutional-neural-networks
#
# #### Tensorflow Data pipeline:
# - https://colab.research.google.com/drive/10EEm-4EKarofyK_nwJnxx1aI6mG0-9HM
#
#
# #### Advanced augmentation:
# - https://colab.research.google.com/drive/128KNUDYzZBIrLL9thwcR7IFpJ7tqMXJK?usp=sharing
#
# #### TensorFlow-GPU + CUDA Installation instructions:
#   - https://medium.com/analytics-vidhya/install-tensorflow-gpu-cuda-in-windows-10-with-easy-to-follow-instructions-614d79782d26
